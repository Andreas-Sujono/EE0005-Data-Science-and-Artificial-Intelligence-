# %% [markdown]
# <h1 style="color:blue;position:fixed;">Exercise 2</h1>

# %% [markdown]
# <h2 style="color:red;"> Problem 1: Data Preparation </h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
df2 = df.select_dtypes(include = 'int64')

# %%
df2.shape
# Out:
# (1460, 35)

# %%
df2.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706           0        150  ...           0           61
# 1         978           0        284  ...         298            0
# 2         486           0        434  ...           0           42
# 3         216           0        540  ...           0           35
# 4         655           0        490  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# BsmtFinSF1       1460 non-null int64
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# TotRmsAbvGrd     1460 non-null int64
# ...

# %%
#drop non-numeric / categorical data
# look categoical data on the documentation/description of each variable
df2 = df2.drop(['MSSubClass','OverallQual'], axis= 1)

# %%
df2.shape
# Out:
# (1460, 33)

# %% [markdown]
# <h2 style="color:red;"> Problem 2: Stastical Summary </h2>

# %%
df2.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   443.639726    46.549315   567.240411  ...
# std      30.202904     20.645407   456.098091   161.319273   441.866955  ...
# ...

# %%
salePrice_data = df2['SalePrice']

# %%
f, axes = plt.subplots(1, 3, figsize=(25,8))

sb.boxplot(salePrice_data, ax = axes[0])
sb.distplot(salePrice_data, kde = False, ax = axes[1])
sb.distplot(salePrice_data, hist = False,ax = axes[2])

# %%
lotArea_data = df2['LotArea']

# %%
f, axes = plt.subplots(1, 3, figsize=(25,8))

sb.boxplot(lotArea_data, ax = axes[0])
sb.distplot(lotArea_data, kde = False, ax = axes[1])
sb.distplot(lotArea_data, hist = False,ax = axes[2])

# %%
sb.jointplot(x = lotArea_data, y = salePrice_data, height = 12)

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([lotArea_data, salePrice_data], axis = 1, join_axes = [lotArea_data.index])

# Calculate the correlation between the two columns/variables
jointDF.corr()
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %%
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
